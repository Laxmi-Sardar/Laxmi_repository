# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action = 'ignore')
data = pd.read_csv('Transformed_Housing_Data2.csv')
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
Y = data['Sale_Price']
X = scaler.fit_transform(data.drop(columns = ['Sale_Price']))
X = pd.DataFrame(data = X, columns = data.drop(columns = ['Sale_Price']).columns)
X.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0       -0.398724        -1.447526            -0.979905           -0.228291
# 1       -0.398724         0.175684             0.533718           -0.189858
# 2       -1.474115        -1.447526            -1.426369           -0.123276
# 3        0.676667         1.149611            -0.130534           -0.243983
# 4       -0.398724        -0.148958            -0.435436           -0.169628
#
#    No of Floors  No of Times Visited  Overall Grade  \
# 0     -0.915389             -0.30579      -0.563993
# 1      0.936817             -0.30579      -0.563993
# 2     -0.915389             -0.30579      -1.468566
# 3     -0.915389             -0.30579      -0.563993
# 4     -0.915389             -0.30579       0.340581
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                  -0.734722                -0.658697
# ...

# %%
X = data.drop(columns = ["Sale_Price"])
Y = data['Sale_Price']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 101)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(x_test)

# %%
lr.score(x_test, y_test)
# Out:
# 0.846235554246901

# %%
##froward selection
def adj_r2( m ,data_y, predictions):
    #calculate adjusted_r2 value
  '''
  m : number of independent variables
  data_y : target variable
  predictions : prediction of the model to be evaluated

  Returns: Adjusted R2
  '''

  from sklearn.metrics import r2_score
  R = r2_score(data_y, predictions)
  n = len(data_y)
  adj_R = 1 - ((1-R)*(n-1))/(n-m-1)
  return adj_R
    
def return_r2(X, Y, model):
  '''
  X : independent variables
  Y : target variable
  model : predictive model

  Returns: Adjusted R2 corresponding to the model
  '''
  model.fit(X, Y)
  pred = model.predict(X)
  m = len(X.columns)
  r2 = adj_r2(m, Y, pred)
  return r2
    
def forward_selection(model, X, Y, max_features):
  '''
  X : independent variables
  Y : target variable
  model : any predictive model
  max_features : selects best feature upto max_features value

  Returns: 
  Rmax : Adjusted R2 of the final model
  history : list of Rmax at every new independent variable added to the model
  x[f_col] : best features upto max_features
  '''
  
  f_col = []#store var being selected at each dtep of forward selection
  history = []#store adj r2 values whenever new feature is selected
  
  for i in range(max_features):#loop until amximum number of featurs are selected

    f_col.append('blank')#updates when we encounter a element for  best feature
    tmp = f_col[:]
    Rmax = -1 #keeps track that adding which variable causes maximum adjuted r2 result

    for var in X.columns:
      tmp[-1] = var#last element of tmp in selected new col to travel if yess update r2
      r2 = return_r2( X[tmp] , Y, model)
      if r2 >= Rmax:#checking weather adding this var leads to highest r2 value 
        Rmax = r2
        f_col[-1] = var# the new variable with highest adjr2 value is retained
        elim = var
  
    print("Selected",f_col[-1],"with new r2 =",Rmax)
    history.append(Rmax)

  return Rmax, history, X[f_col]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

score, history, sel_data = forward_selection(lr, x_train, y_train, 5)
# Out:
# Selected Flat Area (in Sqft) with new r2 = 0.4825106645259518
# Selected Latitude with new r2 = 0.6158682713046579
# Selected Overall Grade with new r2 = 0.669325084451791
# Selected Age of House (in Years) with new r2 = 0.7101671809322654
# Selected Zipcode_Group_Zipcode_Group_8 with new r2 = 0.7359659801896957

# %%
sel_data.columns
# Out:
# Index(['Flat Area (in Sqft)', 'Latitude', 'Overall Grade',
#        'Age of House (in Years)', 'Zipcode_Group_Zipcode_Group_8'],
#       dtype='object')

# %%
score
# Out:
# 0.7359659801896957

# %%
#backward elimination
def adj_r2( m=0, data_y=0, predictions=0):
  '''
  m : number of independent variables
  data_y : target variable
  predictions : prediction of the model to be evaluated

  Returns: Adjusted R2
  '''
  from sklearn.metrics import r2_score
  R = r2_score(data_y, predictions)
  n = len(data_y)
  adj_R = 1 - ((1-R)*(n-1))/(n-m-1)
  return adj_R
    
def return_r2(X, Y, model):
  '''
  X : independent variables
  Y : target variable
  model : predictive model

  Returns: Adjusted R2 corresponding to the model
  '''
  model.fit(X, Y)
  pred = model.predict(X)
  m = len(X.columns)
  r2 = adj_r2(m, Y, pred)
  return r2
    
def backward_elimination( model, X, Y, min_features):
  '''
  X : independent variables
  Y : target variable
  model : predictive model
  min_features : eliminate worst features until only min_features are left

  Returns: 
  Rmax : Adjusted R2 of the final model
  history : list of Rmax at every new independent variable added to the model
  x[f_col] : best features upto max_features
  '''
  elim_data = X[:]#contains all cols in x_train
  r2_history = []#keep track of adiR2 when a feature is eliminated
  base_r2 = return_r2(elim_data, Y, model)#the baseline adjr2 score when independent variables are used to build A LR
  print("base_r2 is", base_r2) 


  for i in range(X.shape[1] - min_features):#run loop until minimu features are accquired
  
    difference = -100

    for var in elim_data.columns:
      tmp = elim_data.drop(columns = [var])
      r2 = return_r2(tmp, Y, model)

      if (r2 - base_r2) > difference:#dropping the feature  had maximum desired effect
        difference = r2 - base_r2
        eliminate = var
        new_r2 = r2
  
    elim_data.drop(columns = [eliminate], inplace = True)
    r2_history.append(new_r2)
    print(eliminate,"Eliminated : New adj_r2 = ",new_r2,)
    base_r2 = new_r2

  return base_r2, r2_history, elim_data

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

score , history, survided_data = backward_elimination(lr, x_train, y_train, 15)
# Out:
# base_r2 is 0.8411713183817103
# Area of the House from Basement (in Sqft) Eliminated : New adj_r2 =  0.841179744665843
# Condition_of_the_House_Okay Eliminated : New adj_r2 =  0.8411623663620637
# No of Floors Eliminated : New adj_r2 =  0.8411171250786783
# Lot Area after Renovation (in Sqft) Eliminated : New adj_r2 =  0.8410610037918913
# No of Bedrooms Eliminated : New adj_r2 =  0.8409159992800564
# Condition_of_the_House_Fair Eliminated : New adj_r2 =  0.8407704362899259
# Condition_of_the_House_Good Eliminated : New adj_r2 =  0.8404605503169833
# Years Since Renovation Eliminated : New adj_r2 =  0.8399491254999183
# Ever_Renovated_Yes Eliminated : New adj_r2 =  0.8394089149738739
# No of Bathrooms Eliminated : New adj_r2 =  0.8384257980145962
# Living Area after Renovation (in Sqft) Eliminated : New adj_r2 =  0.8371253089016231
# Waterfront_View_Yes Eliminated : New adj_r2 =  0.8356698063157927
# Zipcode_Group_Zipcode_Group_1 Eliminated : New adj_r2 =  0.8339600690154836
# ...

# %%
######gpt code
def forward_selection(model, X, Y, max_features):
    '''
    X : independent variables (DataFrame)
    Y : target variable (Series)
    model : predictive model (assumed to be already initialized)
    max_features : selects best feature up to max_features value

    Returns: 
    Rmax : Adjusted R2 of the final model
    history : list of Rmax at every new independent variable added to the model
    X[f_col] : DataFrame containing best features up to max_features
    '''
    f_col = []
    history = []
    selected_features = pd.DataFrame()  # To store the selected features DataFrame
    
    # Fit the model with an empty set of features
    model.fit(pd.DataFrame(), Y)
    current_best_r2 = return_r2(pd.DataFrame(), Y, model)
    history.append(current_best_r2)
    
    for i in range(max_features):
        best_feature = None
        best_r2 = -1
        
        # Find the next best feature to add
        for var in X.columns:
            if var not in f_col:
                tmp_features = f_col + [var]
                r2 = return_r2(X[tmp_features], Y, model)
                
                # Update if this feature improves R2
                if r2 > best_r2:
                    best_r2 = r2
                    best_feature = var
        
        # Add the best feature to the list
        f_col.append(best_feature)
        history.append(best_r2)
        
        # Update the selected features DataFrame
        selected_features = X[f_col]
    
    # Final adjusted R2 of the model with selected features
    Rmax = history[-1]
    
    return Rmax, history, selected_features

# Example usage:
# Assuming X and Y are your data and target variable
# model = YourModel()  # Initialize your predictive model (e.g., LinearRegression, RandomForestRegressor, etc.)
# max_features = 3  # Example: select up to 3 best features

# Rmax, history, selected_features = forward_selection(model, X, Y, max_features)
# print("Final selected features:")
# print(selected_features)
# print("Adjusted R2 of the final model:", Rmax)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

score, history, sel_data = forward_selection(lr, x_train, y_train, 5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       1 from sklearn.linear_model import LinearRegression
#       2 lr = LinearRegression()
# ----> 4 score, history, sel_data = forward_selection(lr, x_train, y_train, 5)
#
# Cell In[17], line 19, in forward_selection(model, X, Y, max_features)
#      16 selected_features = pd.DataFrame()  # To store the selected features DataFrame
#      18 # Fit the model with an empty set of features
# ---> 19 model.fit(pd.DataFrame(), Y)
#      20 current_best_r2 = return_r2(pd.DataFrame(), Y, model)
#      21 history.append(current_best_r2)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
# ...

# %%
history
# Out:
# [0.841179744665843,
#  0.8411623663620637,
#  0.8411171250786783,
#  0.8410610037918913,
#  0.8409159992800564,
#  0.8407704362899259,
#  0.8404605503169833,
#  0.8399491254999183,
#  0.8394089149738739,
#  0.8384257980145962,
#  0.8371253089016231,
#  0.8356698063157927,
#  0.8339600690154836,
#  0.8318506623682476,
#  0.8295620645811876,
#  0.8266049066242156,
#  0.82429217078267,
#  0.8192910381878411,
#  0.813501372362812,
#  0.7999680310309634,
#  0.7819399099884952,
#  0.770302160770225,
#  0.7580319410320749,
#  0.745451210409211,
#  0.7245993616828927,
#  0.7001983572378965,
#  0.669325084451791,
#  0.6158682713046579,
#  0.4825106645259518]

# %%
plt.figure(figsize = (5,5), dpi = 150)
plt.plot(range(len(history),0,-1), history, color = 'red')
plt.xlabel('remaining features')
plt.ylabel('adj-R2 Score')
#plt.yticks([z/100 for z in range()])
plt.title('Backward Elimination')
# Out:
# Text(0.5, 1.0, 'Backward Elimination')
